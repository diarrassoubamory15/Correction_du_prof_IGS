# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
os.chdir(r'C:\Users\Diarrassouba\jupyter_pandas_numpy_matplotlib')

# %%
np.linspace(1,9,5)
#1-3 = -2
#3-5 = -2
#5-7 = -2
#7-9 = -2
# Out:
# array([1., 3., 5., 7., 9.])

# %%
x = np.linspace(0, 2, 10)
y = x**2
z = x**3

# %%
#Pour construire une courbe avec X en abscisse et y en ordonnée
plt.plot(x,y)

# %%
#Changer l'épaisseur et la couleur de la ligne du graphique précédemment créé avec le paramètre "c" et "lw"
plt.plot(x, y, c ='green', lw=6)

# %%
#plt.plot(x, y, c ='red', lw=3, ls='--')

# %%
#Construire sur le même graphique deux courbes
plt.figure()
plt.plot(x, y, label='x**3')
plt.plot(x, x**2, label = 'x**2')
plt.title('Graphique 1')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.savefig('figure1.png')

# %%
#Afficher à travers un boxplot la distribution de x
plt.figure
plt.boxplot(x)
#ajouter un titre au boxplot
#plt.title('Ditribution de la variable x')
#plt.xlabel('x')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19aeb458d08>,
#   <matplotlib.lines.Line2D at 0x19aeb4602c8>],
#  'caps': [<matplotlib.lines.Line2D at 0x19aeb458cc8>,
#   <matplotlib.lines.Line2D at 0x19aeb460588>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19aeb458748>],
#  'medians': [<matplotlib.lines.Line2D at 0x19aeb469088>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19aeb460c08>],
#  'means': []}

# %%
#Pour construire un nuage de points
plt.scatter(x,z)

# %%
#Changer la couleur du graphique
plt.scatter(x, z, c = 'red')

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
w = 0.25

# %%
plt.figure()
plt.bar(labels, men_means, w, label = "Men")
plt.xlabel('Labels')
plt.ylabel('Effectif')
plt.title("Men vs Women")
plt.legend()

# %%
plt.figure()
plt.bar(labels, men_means, w, label = "Men")
plt.bar(labels, women_means, w, bottom=men_means, label = "Women")
plt.xlabel('Labels')
plt.ylabel('Effectif')
plt.title("Men vs Women")
plt.legend()

# %%
w = 0.4
index_1 = np.arange(len(labels))
print(index_1,'\n')
index_2 = [i+w for i in range(len(labels))]
print(index_2)
# Out:
# [0 1 2 3 4]
#
# [0.4, 1.4, 2.4, 3.4, 4.4]

# %%
w = 0.4
index_1 = np.arange(len(labels))
index_2 = [i+w for i in range(len(labels))]
plt.figure()
plt.bar(index_1, men_means, w, label = "Men")
plt.legend()

# %%
#w = 0.4
#index_1 = np.arange(len(labels))
#index_2 = [i+w for i in range(len(labels))]
plt.figure()
plt.bar(index_1, men_means, w, label = "Men")
plt.bar(index_2, women_means, w, label = "Women")
plt.legend()

# %%
#w = 0.4
#index_1 = np.arange(len(labels))
#index_2 = [i+w for i in range(len(labels))]
plt.figure()
plt.bar(index_1, men_means, w, label = "Men")
plt.bar(index_2, women_means, w, label = "Women")
plt.xticks(index_1+w/2)
plt.legend()

# %%
#w = 0.4
#index_1 = np.arange(len(labels))
#index_2 = [i+w for i in range(len(labels))]
plt.figure()
plt.bar(index_1, men_means, w, label = "Men")
plt.bar(index_2, women_means, w, label = "Women")
plt.xticks(index_1+w/2, labels)
plt.legend()

# %%
data = pd.read_excel('Coeur.xlsx')
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140.0        289.0    0  Normal    172    Non
# 1     49  femme  DNA  160.0        180.0    0  Normal    156    Non
# 2     37  homme   AA  130.0        283.0    0      ST     98    Non
# 3     48  femme  ASY  138.0        214.0    0  Normal    108    Oui
# 4     54  homme  DNA  150.0        195.0    0  Normal    122    Non
# ..   ...    ...  ...    ...          ...  ...     ...    ...    ...
# 913   45  homme   AT    NaN        264.0    0  Normal    132    Non
# 914   68  homme  ASY    NaN        193.0    1  Normal    141    Non
# 915   57  homme  ASY    NaN        131.0    0  Normal    115    Oui
# 916   57  femme   AA    NaN        236.0    0     LVH    174    Non
# 917   38  homme  DNA    NaN        175.0    0  Normal    173    Non
#
#      DEPRESSION      PENTE  CŒUR
# 0           0.0  Ascendant     0
# 1           1.0       Plat     1
# 2           0.0  Ascendant     0
# 3           1.5       Plat     1
# 4           0.0  Ascendant     0
# ..          ...        ...   ...
# 913         1.2       Plat     1
# 914         3.4       Plat     1
# 915         1.2       Plat     1
# 916         0.0       Plat     1
# 917         0.0  Ascendant     0
#
# [918 rows x 12 columns]

# %%
data.head()
# Out:
#    AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  DEPRESSION  \
# 0   40  homme   AA  140.0        289.0    0  Normal    172    Non         0.0
# 1   49  femme  DNA  160.0        180.0    0  Normal    156    Non         1.0
# 2   37  homme   AA  130.0        283.0    0      ST     98    Non         0.0
# 3   48  femme  ASY  138.0        214.0    0  Normal    108    Oui         1.5
# 4   54  homme  DNA  150.0        195.0    0  Normal    122    Non         0.0
#
#        PENTE  CŒUR
# 0  Ascendant     0
# 1       Plat     1
# 2  Ascendant     0
# 3       Plat     1
# 4  Ascendant     0

# %%
df = data.copy()

# %%
type(df['AGE'])
# Out:
# pandas.core.series.Series

# %%
type(x)
# Out:
# numpy.ndarray

# %%
#plt.figure
plt.boxplot(df['AGE'])
plt.title('Ditribution de la variable Age')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure()
df.boxplot('AGE')
plt.title('Ditribution de la variable Age')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure()
df.boxplot('AGE', by='CŒUR')
# Out:
# <AxesSubplot:title={'center':'AGE'}, xlabel='CŒUR'>

# %%
plt.figure()
plt.hist(df['AGE'])
# Out:
# (array([ 12.,  37.,  86., 104., 148., 201., 175., 101.,  39.,  15.]),
#  array([28. , 32.9, 37.8, 42.7, 47.6, 52.5, 57.4, 62.3, 67.2, 72.1, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure()
df.hist('AGE', by='CŒUR')
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %%
plt.figure()
df.boxplot('AGE', by='SEXE')
# Out:
# <AxesSubplot:title={'center':'AGE'}, xlabel='SEXE'>

# %%
plt.figure()
df['AGE'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure()
plt.pie(df['ANGINE'].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x19aeed13588>,
#   <matplotlib.patches.Wedge at 0x19aeed26648>],
#  [Text(-0.32483074820260877, 1.050944805887604, ''),
#   Text(0.32483064980605275, -1.050944836300449, '')])

# %%
df['ANGINE'].value_counts()
# Out:
# Non    546
# Oui    371
# Name: ANGINE, dtype: int64

# %%
plt.figure()
df['ANGINE'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='ANGINE'>

# %%
plt.figure()
df['PENTE'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Quantitative vs Quantitative

# %%
plt.figure()
plt.scatter(df['AGE'], df['CHOLESTEROL'])

# %%
code_coeur = df['CŒUR'].astype('category').cat.codes
plt.figure()
df.plot.scatter('AGE', 'CHOLESTEROL', c=df['CŒUR'].astype('category').cat.codes)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='CHOLESTEROL'>

# %%
code_coeur = df['CŒUR'].astype('category').cat.codes
plt.figure()
df.plot.scatter('PAR', 'DEPRESSION ', c=np.array(['blue','green'])[code_coeur])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DEPRESSION '
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-06abdebe9dbc> in <module>
#       1 code_coeur = df['CŒUR'].astype('category').cat.codes
#       2 plt.figure()
# ----> 3 df.plot.scatter('PAR', 'DEPRESSION ', c=np.array(['blue','green'])[code_coeur])
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwargs)
#    1497             ...                       colormap='viridis')
#    1498         """
# -> 1499         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1500
#    1501     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
#     794                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#     969         scatter = ax.scatter(
#     970             data[x].values,
# --> 971             data[y].values,
#     972             c=c_values,
#     973             label=label,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DEPRESSION '
